# %% [markdown]
# # Lesson 3 Class Exercises: Pandas Part 1
#
# With these class exercises we learn a few new things.  When new knowledge is introduced you'll see the icon shown on the right:
# <span style="float:right; margin-left:10px; clear:both;">![Task](../media/new_knowledge.png)</span>

# %% [markdown]
# ## Reminder
# The first checkin-in of the project is due next Tueday.  After today, you should have everything you need to know to accomplish that first part.

# %% [markdown]
# ## Get Started
# Import the Numpy and Pandas packages

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Exercise 1: Import Iris Data
# Import the Iris dataset made available to you in the last class period for the Numpy part2 exercises. Save it to a variable naemd `iris`. Print the first 5 rows and the dimensions to ensure it was read in properly.

# %%
iris = pd.read_csv('../../data/iris.csv')
iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %% [markdown]
# Notice how much easier this was to import compared to the Numpy `genfromtxt`. We did not have to skip the headers, we did not have to specify the data type and we can have mixed data types in the same matrix.

# %% [markdown]
# ## Exercise 2: Import Legislators Data
# For portions of this notebook we will use a public dataset that contains all of the current legistators of the United States Congress. This dataset can be found [here](https://github.com/unitedstates/congress-legislators).
#
# Import the data directly from this URL:  https://theunitedstates.io/congress-legislators/legislators-current.csv
#
# Save the data in a variable named `legislators`. Print the first 5 lines, and the dimensions. You can get the dimensions of the dataframe using the `.shape` member variable.

# %%
legislators = pd.read_csv("https://theunitedstates.io/congress-legislators/legislators-current.csv")
legislators.head()
# Out:
#   last_name first_name middle_name suffix nickname             full_name  \
# 0     Brown    Sherrod         NaN    NaN      NaN         Sherrod Brown
# 1  Cantwell      Maria         NaN    NaN      NaN        Maria Cantwell
# 2    Cardin   Benjamin          L.    NaN      NaN    Benjamin L. Cardin
# 3    Carper     Thomas     Richard    NaN      NaN      Thomas R. Carper
# 4     Casey     Robert          P.    Jr.      Bob  Robert P. Casey, Jr.
#
#      birthday gender type state  ...  opensecrets_id  lis_id  \
# 0  1952-11-09      M  sen    OH  ...       N00003535    S307
# 1  1958-10-13      F  sen    WA  ...       N00007836    S275
# 2  1943-10-05      M  sen    MD  ...       N00001955    S308
# 3  1947-01-23      M  sen    DE  ...       N00012508    S277
# 4  1960-04-13      M  sen    PA  ...       N00027503    S309
#
#                fec_ids cspan_id govtrack_id votesmart_id  ballotpedia_id  \
# 0  H2OH13033,S6OH00163   5051.0      400050      27018.0   Sherrod Brown
# 1  S8WA00194,H2WA01054  26137.0      300018      27122.0  Maria Cantwell
# 2  H6MD03177,S6MD03177   4004.0      400064      26888.0      Ben Cardin
# 3            S8DE00079    663.0      300019      22421.0      Tom Carper
# 4            S6PA00217  47036.0      412246       2541.0  Bob Casey, Jr.
#
#   washington_post_id icpsr_id    wikipedia_id
# 0                NaN  29389.0   Sherrod Brown
# 1                NaN  39310.0  Maria Cantwell
# 2                NaN  15408.0      Ben Cardin
# 3                NaN  15015.0      Tom Carper
# 4                NaN  40703.0   Bob Casey Jr.
#
# [5 rows x 34 columns]

# %% [markdown]
# ## Exercise 3: Explore the Data
# ### Task 1
# Print the column names of the legistators dataframe and explore the type of data in the data frame.

# %%
legislators.columns
# Out:
# Index(['last_name', 'first_name', 'middle_name', 'suffix', 'nickname',
#        'full_name', 'birthday', 'gender', 'type', 'state', 'district',
#        'senate_class', 'party', 'url', 'address', 'phone', 'contact_form',
#        'rss_url', 'twitter', 'facebook', 'youtube', 'youtube_id',
#        'bioguide_id', 'thomas_id', 'opensecrets_id', 'lis_id', 'fec_ids',
#        'cspan_id', 'govtrack_id', 'votesmart_id', 'ballotpedia_id',
#        'washington_post_id', 'icpsr_id', 'wikipedia_id'],
#       dtype='object')

# %% [markdown]
# ### Task 2
# Show the data types of all of the columns in the legislator data. To do this, use the `.dtypes` member variable. Do all of the data types seem appropriate for the data?

# %%
legislators.dtypes
# Out:
# last_name              object
# first_name             object
# middle_name            object
# suffix                 object
# nickname               object
# full_name              object
# birthday               object
# gender                 object
# type                   object
# state                  object
# district              float64
# senate_class          float64
# party                  object
# url                    object
# address                object
# phone                  object
# contact_form           object
# rss_url                object
# twitter                object
# facebook               object
# youtube                object
# youtube_id             object
# bioguide_id            object
# thomas_id             float64
# opensecrets_id         object
# lis_id                 object
# fec_ids                object
# cspan_id              float64
# govtrack_id             int64
# votesmart_id          float64
# ballotpedia_id         object
# washington_post_id    float64
# icpsr_id              float64
# wikipedia_id           object
# dtype: object

# %% [markdown]
# Show all of the data types in the iris dataframe. To do this, use the `.dtypes` member variable.

# %%
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %% [markdown]
# ### Task 3
# It's always important to know where the missing values are in your data. Are there any missing values in the legislators dataframe? How many per column?
#
# Hint: we didn't learn how to find missing values in the lesson, but we can use the `isna()` function.

# %%
legislators.isna().sum()
# Out:
# last_name               0
# first_name              0
# middle_name           290
# suffix                519
# nickname              496
# full_name               0
# birthday                0
# gender                  0
# type                    0
# state                   0
# district              100
# senate_class          437
# party                   0
# url                     0
# address                 0
# phone                   0
# contact_form          437
# rss_url               280
# twitter                10
# facebook              162
# youtube               269
# youtube_id            193
# bioguide_id             0
# thomas_id             206
# opensecrets_id         63
# lis_id                437
# fec_ids                 1
# cspan_id              153
# govtrack_id             0
# votesmart_id           58
# ballotpedia_id         45
# washington_post_id    537
# icpsr_id               73
# wikipedia_id            1
# dtype: int64

# %% [markdown]
# How about in the iris dataframe?

# %%
iris.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# ### Task 4
# It is also important to know if you have any duplicated rows. If you are performing statistcal analyses and you have duplicated entries they can affect the results.  So, let's find out.  Are there any duplicated rows in the legislators dataframe?  Print then number of duplicates. If there are duplicates print the rows. What function could we used to find out if we have duplicated rows?

# %%
legislators.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Do we have duplicated rows in the iris dataset? Print the number of duplicates? If there are duplicates print the rows.

# %%
iris.duplicated().sum()
# Out:
# 3

# %%
iris[iris.duplicated()]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 34            4.9          3.1           1.5          0.1     setosa
# 37            4.9          3.1           1.5          0.1     setosa
# 142           5.8          2.7           5.1          1.9  virginica

# %% [markdown]
# If there are duplicated rows should we remove them or keep them?

# %% [markdown]
# ### Task 5
# It is important to also check that the range of values in our data matches expectations.  For example, if we expect to have three species in our iris data, we should check that we see three species. How many political parties should we expect in the legislators data?  If we saw not what we expect perhaps the data is incomplete.... Let's check.   You can find out how many unique values there are per column using the `.nunique()` function.  Try it for both the legislators and the iris data set.

# %%
legislators.nunique()
# Out:
# last_name             490
# first_name            322
# middle_name            88
# suffix                  5
# nickname               32
# full_name             537
# birthday              529
# gender                  2
# type                    2
# state                  56
# district               54
# senate_class            3
# party                   3
# url                   537
# address               537
# phone                 537
# contact_form          100
# rss_url               256
# twitter               527
# facebook              375
# youtube               268
# youtube_id            344
# bioguide_id           537
# thomas_id             331
# opensecrets_id        474
# lis_id                100
# fec_ids               536
# cspan_id              384
# govtrack_id           537
# votesmart_id          479
# ballotpedia_id        492
# washington_post_id      0
# icpsr_id              464
# wikipedia_id          536
# dtype: int64

# %%
legislators['state'].unique()
# Out:
# array(['OH', 'WA', 'MD', 'DE', 'PA', 'CA', 'MN', 'NJ', 'VT', 'MI', 'MT',
#        'RI', 'WY', 'MS', 'ME', 'TX', 'IL', 'SC', 'OK', 'KY', 'OR', 'ID',
#        'NH', 'VA', 'NY', 'WV', 'AL', 'WI', 'CO', 'FL', 'GA', 'TN', 'CT',
#        'MO', 'AR', 'IN', 'NC', 'LA', 'NE', 'AZ', 'IA', 'NM', 'HI', 'ND',
#        'MA', 'UT', 'KS', 'AK', 'DC', 'MP', 'SD', 'NV', 'VI', 'AS', 'PR',
#        'GU'], dtype=object)

# %%
iris.nunique()
# Out:
# sepal_length    35
# sepal_width     23
# petal_length    43
# petal_width     22
# species          3
# dtype: int64

# %% [markdown]
# What do you think?  Do we see what we might expect?  Are there fields where this type of check doesn't matter? In what fields might this type of exploration matter?

# %% [markdown]
# Check to see if you have all of the values expected for a given field. Pick a column you know should have a set number of values and print all of the unique values in that column. Do so for both the legislator and iris datasets.

# %%
legislators['gender'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
iris['sepal_length'].unique()
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.4, 4.8, 4.3, 5.8, 5.7, 5.2, 5.5,
#        4.5, 5.3, 7. , 6.4, 6.9, 6.5, 6.3, 6.6, 5.9, 6. , 6.1, 5.6, 6.7,
#        6.2, 6.8, 7.1, 7.6, 7.3, 7.2, 7.7, 7.4, 7.9])

# %% [markdown]
# ## Exercise 5: Describe the data
# For both the legislators and the iris data, get descriptive statistics for each numeric field.

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
legislators.describe()
# Out:
#          district  senate_class    thomas_id      cspan_id    govtrack_id  \
# count  437.000000    100.000000   331.000000  3.840000e+02     537.000000
# mean    10.057208      2.010000  1747.000000  5.407115e+05  411687.761639
# std     10.686480      0.822598   549.070697  1.486116e+06   26882.053677
# min      0.000000      1.000000    91.000000  2.600000e+02  300018.000000
# 25%      3.000000      1.000000  1618.500000  4.554975e+04  412196.000000
# 50%      6.000000      2.000000  1922.000000  7.970400e+04  412566.000000
# 75%     13.000000      3.000000  2125.000000  1.002813e+06  412766.000000
# max     53.000000      3.000000  2296.000000  9.275683e+06  456858.000000
#
#         votesmart_id  washington_post_id      icpsr_id
# count     479.000000                 0.0    464.000000
# mean    75401.068894                 NaN  24263.346983
# std     62274.515870                 NaN   7507.728202
# min       119.000000                 NaN  14066.000000
# 25%     22465.500000                 NaN  21107.500000
# 50%     52662.000000                 NaN  21564.500000
# 75%    133665.000000                 NaN  21972.250000
# max    188334.000000                 NaN  94659.000000

# %% [markdown]
# ## Exercise 6: Row Index Labels
# For the legislator dataframe, let's change the row labels from numerical indexes to something more recognizable.  Take a look at the columns of data, is there anything you might want to substitue as a row label?  Pick one and set the index lables. Then print the top 5 rows to see if the index labels are present.

# %%
legislators.index = legislators['last_name']
legislators.head()
# Out:
#           last_name first_name middle_name suffix nickname  \
# last_name
# Brown         Brown    Sherrod         NaN    NaN      NaN
# Cantwell   Cantwell      Maria         NaN    NaN      NaN
# Cardin       Cardin   Benjamin          L.    NaN      NaN
# Carper       Carper     Thomas     Richard    NaN      NaN
# Casey         Casey     Robert          P.    Jr.      Bob
#
#                       full_name    birthday gender type state  ...  \
# last_name                                                      ...
# Brown             Sherrod Brown  1952-11-09      M  sen    OH  ...
# Cantwell         Maria Cantwell  1958-10-13      F  sen    WA  ...
# Cardin       Benjamin L. Cardin  1943-10-05      M  sen    MD  ...
# Carper         Thomas R. Carper  1947-01-23      M  sen    DE  ...
# Casey      Robert P. Casey, Jr.  1960-04-13      M  sen    PA  ...
#
#            opensecrets_id  lis_id              fec_ids cspan_id govtrack_id  \
# last_name
# Brown           N00003535    S307  H2OH13033,S6OH00163   5051.0      400050
# Cantwell        N00007836    S275  S8WA00194,H2WA01054  26137.0      300018
# Cardin          N00001955    S308  H6MD03177,S6MD03177   4004.0      400064
# Carper          N00012508    S277            S8DE00079    663.0      300019
# Casey           N00027503    S309            S6PA00217  47036.0      412246
#
#           votesmart_id  ballotpedia_id washington_post_id icpsr_id  \
# last_name
# Brown          27018.0   Sherrod Brown                NaN  29389.0
# Cantwell       27122.0  Maria Cantwell                NaN  39310.0
# Cardin         26888.0      Ben Cardin                NaN  15408.0
# Carper         22421.0      Tom Carper                NaN  15015.0
# Casey           2541.0  Bob Casey, Jr.                NaN  40703.0
#
#              wikipedia_id
# last_name
# Brown       Sherrod Brown
# Cantwell   Maria Cantwell
# Cardin         Ben Cardin
# Carper         Tom Carper
# Casey       Bob Casey Jr.
#
# [5 rows x 34 columns]

# %%
legislators.loc['Graham']
# Out:
# last_name                                                        Graham
# first_name                                                      Lindsey
# middle_name                                                          O.
# suffix                                                              NaN
# nickname                                                            NaN
# full_name                                                Lindsey Graham
# birthday                                                     1955-07-09
# gender                                                                M
# type                                                                sen
# state                                                                SC
# district                                                            NaN
# senate_class                                                          2
# party                                                        Republican
# url                               https://www.lgraham.senate.gov/public
# address               290 Russell Senate Office Building Washington ...
# phone                                                      202-224-5972
# contact_form          https://www.lgraham.senate.gov/public/index.cf...
# rss_url               http://www.lgraham.senate.gov/public/index.cfm...
# twitter                                                      GrahamBlog
# facebook                                         USSenatorLindseyGraham
# youtube                                              USSenLindseyGraham
# youtube_id                                     UClLGZMA5Ei2Z8fR1PLEx6yQ
# bioguide_id                                                     G000359
# thomas_id                                                           452
# opensecrets_id                                                N00009975
# lis_id                                                             S293
# fec_ids                                             S0SC00149,H4SC03087
# cspan_id                                                          36782
# govtrack_id                                                      300047
# votesmart_id                                                      21992
# ballotpedia_id                                           Lindsey Graham
# washington_post_id                                                  NaN
# icpsr_id                                                          29566
# wikipedia_id                                             Lindsey Graham
# Name: Graham, dtype: object

# %% [markdown]
# ## Exercise 7: Indexing & Sampling
# Randomly select 15 Republicans or Democrats (your choice) from the senate.

# %%
legislators[(legislators['type'] == 'sen') & 
            (legislators['party'] == 'Democrat')].sample(15)
# Out:
#              last_name first_name middle_name suffix nickname  \
# last_name
# Casey            Casey     Robert          P.    Jr.      Bob
# Schumer        Schumer    Charles          E.    NaN    Chuck
# Merkley        Merkley       Jeff         NaN    NaN      NaN
# Blumenthal  Blumenthal    Richard         NaN    NaN      NaN
# Duckworth    Duckworth      Tammy         NaN    NaN      NaN
# Leahy            Leahy    Patrick          J.    NaN      NaN
# Cardin          Cardin   Benjamin          L.    NaN      NaN
# Feinstein    Feinstein     Dianne         NaN    NaN      NaN
# Schatz          Schatz      Brian     Emanuel    NaN      NaN
# Padilla        Padilla  Alejandro         NaN    NaN     Alex
# Cantwell      Cantwell      Maria         NaN    NaN      NaN
# Kelly            Kelly       Mark         NaN    NaN      NaN
# Baldwin        Baldwin      Tammy         NaN    NaN      NaN
# Luján            Luján        Ben         Ray    NaN      NaN
# Hassan          Hassan   Margaret        Wood    NaN   Maggie
#
#                        full_name    birthday gender type state  ...  \
# last_name                                                       ...
# Casey       Robert P. Casey, Jr.  1960-04-13      M  sen    PA  ...
# Schumer       Charles E. Schumer  1950-11-23      M  sen    NY  ...
# Merkley             Jeff Merkley  1956-10-24      M  sen    OR  ...
# Blumenthal    Richard Blumenthal  1946-02-13      M  sen    CT  ...
# Duckworth        Tammy Duckworth  1968-03-12      F  sen    IL  ...
# Leahy           Patrick J. Leahy  1940-03-31      M  sen    VT  ...
# Cardin        Benjamin L. Cardin  1943-10-05      M  sen    MD  ...
# Feinstein       Dianne Feinstein  1933-06-22      F  sen    CA  ...
# Schatz              Brian Schatz  1972-10-20      M  sen    HI  ...
# Padilla             Alex Padilla  1973-03-22      M  sen    CA  ...
# Cantwell          Maria Cantwell  1958-10-13      F  sen    WA  ...
# Kelly                 Mark Kelly  1964-02-21      M  sen    AZ  ...
# Baldwin            Tammy Baldwin  1962-02-11      F  sen    WI  ...
# Luján              Ben Ray Luján  1972-06-07      M  sen    NM  ...
# Hassan      Margaret Wood Hassan  1958-02-27      F  sen    NH  ...
#
#             opensecrets_id  lis_id              fec_ids   cspan_id  \
# last_name
# Casey            N00027503    S309            S6PA00217    47036.0
# Schumer          N00001093    S270  S8NY00082,H0NY16010     5929.0
# Merkley          N00029303    S322            S8OR00207  1029842.0
# Blumenthal       N00031685    S341            S0CT00177    21799.0
# Duckworth        N00027860    S386  H6IL06141,S6IL00292    94484.0
# Leahy            N00009918    S057            S4VT00017     1552.0
# Cardin           N00001955    S308  H6MD03177,S6MD03177     4004.0
# Feinstein        N00007364    S221            S0CA00199    13061.0
# Schatz           N00028138    S353  S4HI00136,H6HI02244    87784.0
# Padilla                NaN    S413                  NaN        NaN
# Cantwell         N00007836    S275  S8WA00194,H2WA01054    26137.0
# Kelly            N00044223    S406            S0AZ00350        NaN
# Baldwin          N00004367    S354  H8WI00018,S2WI00219    57884.0
# Luján            N00029562    S409  H8NM03196,S0NM00058  1031351.0
# Hassan           N00038397    S388            S6NH00091    67481.0
#
#            govtrack_id votesmart_id      ballotpedia_id washington_post_id  \
# last_name
# Casey           412246       2541.0      Bob Casey, Jr.                NaN
# Schumer         300087      26976.0       Chuck Schumer                NaN
# Merkley         412325      23644.0        Jeff Merkley                NaN
# Blumenthal      412490       1568.0  Richard Blumenthal                NaN
# Duckworth       412533      57442.0     Tammy Duckworth                NaN
# Leahy           300065      53353.0       Patrick Leahy                NaN
# Cardin          400064      26888.0          Ben Cardin                NaN
# Feinstein       300043      53273.0    Dianne Feinstein                NaN
# Schatz          412507      17852.0     Brian E. Schatz                NaN
# Padilla         456856          NaN        Alex Padilla                NaN
# Cantwell        300018      27122.0      Maria Cantwell                NaN
# Kelly           456794          NaN          Mark Kelly                NaN
# Baldwin         400013       3470.0       Tammy Baldwin                NaN
# Luján           412293     102842.0       Ben Ray Luján                NaN
# Hassan          412680      42552.0       Maggie Hassan                NaN
#
#            icpsr_id        wikipedia_id
# last_name
# Casey       40703.0       Bob Casey Jr.
# Schumer     14858.0       Chuck Schumer
# Merkley     40908.0        Jeff Merkley
# Blumenthal  41101.0  Richard Blumenthal
# Duckworth   21325.0     Tammy Duckworth
# Leahy       14307.0       Patrick Leahy
# Cardin      15408.0          Ben Cardin
# Feinstein   49300.0    Dianne Feinstein
# Schatz      41112.0        Brian Schatz
# Padilla         NaN        Alex Padilla
# Cantwell    39310.0      Maria Cantwell
# Kelly           NaN          Mark Kelly
# Baldwin     29940.0       Tammy Baldwin
# Luján       20932.0       Ben Ray Luján
# Hassan      41702.0       Maggie Hassan
#
# [15 rows x 34 columns]

# %% [markdown]
# ## Exercise 8: Dates
# <span style="float:right; margin-left:10px; clear:both;">![Task](../media/new_knowledge.png)</span>
# Let's learn something not covered in the Pandas 1 lesson regarding dates.  We have the birthdates for each legislator, but they are in a String format.  Let's convert it to a datetime object. We can do this using the `pd.to_datetime` function.  Take a look at the online documentation to see how to use this function. Convert the `legislators['birthday']` column to a `datetime` object. Confirm that the column is now a datetime object.

# %%
legislators['birthday'] = pd.to_datetime(legislators['birthday'])
legislators['birthday'].head()
# Out:
# last_name
# Brown      1952-11-09
# Cantwell   1958-10-13
# Cardin     1943-10-05
# Carper     1947-01-23
# Casey      1960-04-13
# Name: birthday, dtype: datetime64[ns]

# %% [markdown]
# Now that we have the birthdays in a `datetime` object, how can we calculate their age?  Hint: we can use the `pd.Timestamp.now()` function to get a datetime object for this moment. Let's subtract the current time from their birthdays.  Print the top 5 results.

# %%
(pd.Timestamp.now() - legislators['birthday']).head()
# Out:
# last_name
# Brown      24964 days 11:02:09.308895
# Cantwell   22800 days 11:02:09.308895
# Cardin     28287 days 11:02:09.308895
# Carper     27081 days 11:02:09.308895
# Casey      22252 days 11:02:09.308895
# Name: birthday, dtype: timedelta64[ns]

# %% [markdown]
# Notice that the result of subtracting two `datetime` objects is a `timedelta` object. It contains the difference between two time values. The value we calculated therefore gives us the number of days old.  However, we want the number of years.
#
# To get the number of years we can divide the number of days old by the number of days in a year (i.e. 365). However, we need to extract out the days from the `datetime` object. To get this, the Pandas Series object has an accessor for extracting components of `datetime` objects and `timedelta` objects. It's named `dt` and it works for both.  You can learn more about the attributes of this accessor at the [datetime objects page](https://pandas.pydata.org/pandas-docs/stable/reference/series.html#datetime-properties) and the [timedelta objects page](https://pandas.pydata.org/pandas-docs/stable/reference/series.html#timedelta-properties) by clicking.  Take a moment to look over that documentation.
#
# How would then extract the days in order to divide by 365 to get the years?  Once you've figurd it out. Do so, convert the years to an integer and add the resulting series back into the legislator dataframe as a new column named `age`.  Hint: use the [astype](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.astype.html) function of Pandas to convert the type.

# %%
legislators['age']=((pd.Timestamp.now() - legislators['birthday']).dt.days /365).astype('int')

# %% [markdown]
# Next, find the youngest, oldest and average age of all legislators

# %%
legislators['age'].describe()
# Out:
# count    537.000000
# mean      58.981378
# std       11.953721
# min       25.000000
# 25%       50.000000
# 50%       60.000000
# 75%       68.000000
# max       87.000000
# Name: age, dtype: float64

# %% [markdown]
# Who are the oldest and youngest legislators?

# %%
legislators[(legislators['age'] == legislators['age'].min())]
# Out:
#           last_name first_name middle_name suffix nickname         full_name  \
# last_name
# Cawthorn   Cawthorn      David         NaN    NaN  Madison  Madison Cawthorn
#
#             birthday gender type state  ...  lis_id    fec_ids cspan_id  \
# last_name                               ...
# Cawthorn  1995-08-01      M  rep    NC  ...     NaN  H0NC11233      NaN
#
#           govtrack_id votesmart_id    ballotpedia_id washington_post_id  \
# last_name
# Cawthorn       456833          NaN  Madison Cawthorn                NaN
#
#           icpsr_id      wikipedia_id age
# last_name
# Cawthorn       NaN  Madison Cawthorn  25
#
# [1 rows x 35 columns]

# %%
legislators[(legislators['age'] == legislators['age'].max())]
# Out:
#            last_name first_name middle_name suffix nickname         full_name  \
# last_name
# Feinstein  Feinstein     Dianne         NaN    NaN      NaN  Dianne Feinstein
# Grassley    Grassley    Charles          E.    NaN    Chuck    Chuck Grassley
# Young          Young        Don          E.    NaN      NaN         Don Young
#
#             birthday gender type state  ...  lis_id    fec_ids cspan_id  \
# last_name                               ...
# Feinstein 1933-06-22      F  sen    CA  ...    S221  S0CA00199  13061.0
# Grassley  1933-09-17      M  sen    IA  ...    S153  S0IA00028   1167.0
# Young     1933-06-09      M  rep    AK  ...     NaN  H6AK00045   1897.0
#
#           govtrack_id votesmart_id    ballotpedia_id washington_post_id  \
# last_name
# Feinstein      300043      53273.0  Dianne Feinstein                NaN
# Grassley       300048      53293.0    Chuck Grassley                NaN
# Young          400440      26717.0         Don Young                NaN
#
#           icpsr_id      wikipedia_id age
# last_name
# Feinstein  49300.0  Dianne Feinstein  87
# Grassley   14226.0    Chuck Grassley  87
# Young      14066.0         Don Young  87
#
# [3 rows x 35 columns]

# %% [markdown]
# ## Exercise 9:  Indexing with loc and iloc
# Reindex the legislators dataframe using the state, and find all legislators from a state of your choice using the `loc` accessor.

# %%
legislators.index = legislators['state']
legislators.loc['NY']
# Out:
#            last_name  first_name middle_name suffix nickname  \
# state
# NY        Gillibrand     Kirsten          E.    NaN      NaN
# NY            Clarke      Yvette          D.    NaN      NaN
# NY           Higgins       Brian          M.    NaN      NaN
# NY           Maloney     Carolyn          B.    NaN      NaN
# NY             Meeks     Gregory          W.    NaN      NaN
# NY            Nadler     Jerrold          L.    NaN      NaN
# NY              Reed         Tom          W.    NaN      NaN
# NY           Schumer     Charles          E.    NaN    Chuck
# NY             Tonko        Paul         NaN    NaN      NaN
# NY         Velázquez       Nydia          M.    NaN      NaN
# NY              Meng       Grace         NaN    NaN      NaN
# NY          Jeffries      Hakeem          S.    NaN      NaN
# NY           Maloney        Sean     Patrick    NaN      NaN
# NY            Zeldin         Lee          M.    NaN      NaN
# NY              Rice    Kathleen          M.    NaN      NaN
# NY          Stefanik       Elise          M.    NaN      NaN
# NY             Katko        John         NaN    NaN      NaN
# NY            Suozzi      Thomas          R.    NaN      NaN
# NY         Espaillat     Adriano         NaN    NaN      NaN
# NY           Morelle      Joseph          D.    NaN      NaN
# NY     Ocasio-Cortez  Alexandria         NaN    NaN      NaN
# NY           Delgado     Antonio         NaN    NaN      NaN
# NY            Jacobs       Chris         NaN    NaN      NaN
# NY         Garbarino      Andrew          R.    NaN      NaN
# NY       Malliotakis      Nicole         NaN    NaN      NaN
# NY            Torres     Ritchie        John    NaN      NaN
# NY            Bowman      Jamaal         NaN    NaN      NaN
# NY             Jones    Mondaire         NaN    NaN      NaN
# NY            Tenney     Claudia         NaN    NaN      NaN
#
#                       full_name   birthday gender type state  ...  lis_id  \
# state                                                         ...
# NY        Kirsten E. Gillibrand 1966-12-09      F  sen    NY  ...    S331
# NY             Yvette D. Clarke 1964-11-21      F  rep    NY  ...     NaN
# NY                Brian Higgins 1959-10-06      M  rep    NY  ...     NaN
# NY           Carolyn B. Maloney 1946-02-19      F  rep    NY  ...     NaN
# NY             Gregory W. Meeks 1953-09-25      M  rep    NY  ...     NaN
# NY               Jerrold Nadler 1947-06-13      M  rep    NY  ...     NaN
# NY                     Tom Reed 1971-11-18      M  rep    NY  ...     NaN
# NY           Charles E. Schumer 1950-11-23      M  sen    NY  ...    S270
# NY                   Paul Tonko 1949-06-18      M  rep    NY  ...     NaN
# NY           Nydia M. Velázquez 1953-03-28      F  rep    NY  ...     NaN
# NY                   Grace Meng 1975-10-01      F  rep    NY  ...     NaN
# NY           Hakeem S. Jeffries 1970-08-04      M  rep    NY  ...     NaN
# NY         Sean Patrick Maloney 1966-07-30      M  rep    NY  ...     NaN
# NY                Lee M. Zeldin 1980-01-30      M  rep    NY  ...     NaN
# NY             Kathleen M. Rice 1965-02-15      F  rep    NY  ...     NaN
# NY            Elise M. Stefanik 1984-07-02      F  rep    NY  ...     NaN
# NY                   John Katko 1962-11-09      M  rep    NY  ...     NaN
# NY             Thomas R. Suozzi 1962-08-31      M  rep    NY  ...     NaN
# NY            Adriano Espaillat 1954-09-27      M  rep    NY  ...     NaN
# NY            Joseph D. Morelle 1957-04-29      M  rep    NY  ...     NaN
# NY     Alexandria Ocasio-Cortez 1989-10-13      F  rep    NY  ...     NaN
# NY              Antonio Delgado 1977-01-19      M  rep    NY  ...     NaN
# NY                 Chris Jacobs 1966-11-28      M  rep    NY  ...     NaN
# NY          Andrew R. Garbarino 1984-09-27      M  rep    NY  ...     NaN
# NY           Nicole Malliotakis 1980-11-11      F  rep    NY  ...     NaN
# NY               Ritchie Torres 1988-03-12      M  rep    NY  ...     NaN
# NY                Jamaal Bowman 1976-04-01      M  rep    NY  ...     NaN
# NY               Mondaire Jones 1987-05-18      M  rep    NY  ...     NaN
# NY               Claudia Tenney 1961-02-04      F  rep    NY  ...     NaN
#
#                    fec_ids   cspan_id govtrack_id votesmart_id  \
# state
# NY     H6NY20167,S0NY00410  1022862.0      412223      65147.0
# NY               H4NY11138  1022875.0      412221      44741.0
# NY               H4NY27076  1013050.0      400641      23127.0
# NY               H2NY14037    26162.0      400251      26978.0
# NY               H8NY06048    53469.0      400271       4360.0
# NY               H2NY17071    26159.0      400289      26980.0
# NY               H0NY29054   623468.0      412393     127046.0
# NY     S8NY00082,H0NY16010     5929.0      300087      26976.0
# NY               H8NY21203  1031353.0      412319       4403.0
# NY               H2NY00010    26160.0      400416      26975.0
# NY               H2NY06116    68411.0      412560      69157.0
# NY               H2NY10092    79612.0      412561      55285.0
# NY               H2NY22139    79760.0      412562     139760.0
# NY               H8NY01148    61616.0      412646     110252.0
# NY               H4NY04075    76332.0      412647     127653.0
# NY               H4NY21079    76364.0      412648     152539.0
# NY               H4NY24073    76367.0      412649     152546.0
# NY               H6NY03247   104747.0      412717      92111.0
# NY               H2NY13096    68413.0      412718      14379.0
# NY               H8NY25105        NaN      412749       4362.0
# NY               H8NY15148        NaN      412804     180416.0
# NY               H8NY19181        NaN      412805     180313.0
# NY               H0NY27090        NaN      456793          NaN
# NY               H0NY02234        NaN      456836          NaN
# NY               H0NY11078        NaN      456837          NaN
# NY               H0NY15160        NaN      456838          NaN
# NY               H0NY16143        NaN      456839          NaN
# NY               H0NY17174        NaN      456840          NaN
# NY               H4NY22051   103481.0      412720     127668.0
#
#                    ballotpedia_id washington_post_id icpsr_id  \
# state
# NY             Kirsten Gillibrand                NaN  20735.0
# NY               Yvette D. Clarke                NaN  20733.0
# NY                  Brian Higgins                NaN  20519.0
# NY             Carolyn B. Maloney                NaN  29379.0
# NY                  Gregory Meeks                NaN  29776.0
# NY                 Jerrold Nadler                NaN  29377.0
# NY            Tom Reed (New York)                NaN  21101.0
# NY                  Chuck Schumer                NaN  14858.0
# NY                     Paul Tonko                NaN  20934.0
# NY                Nydia Velazquez                NaN  29378.0
# NY                     Grace Meng                NaN  21342.0
# NY                Hakeem Jeffries                NaN  21343.0
# NY                   Sean Maloney                NaN  21344.0
# NY                     Lee Zeldin                NaN  21539.0
# NY                  Kathleen Rice                NaN  21540.0
# NY                 Elise Stefanik                NaN  21541.0
# NY                     John Katko                NaN  21542.0
# NY                     Tom Suozzi                NaN  21747.0
# NY              Adriano Espaillat                NaN  21715.0
# NY                 Joseph Morelle                NaN  21761.0
# NY       Alexandria Ocasio-Cortez                NaN  21949.0
# NY     Antonio Delgado (New York)                NaN  21916.0
# NY             Christopher Jacobs                NaN      NaN
# NY                            NaN                NaN      NaN
# NY                            NaN                NaN      NaN
# NY                 Ritchie Torres                NaN      NaN
# NY                  Jamaal Bowman                NaN      NaN
# NY                 Mondaire Jones                NaN      NaN
# NY                 Claudia Tenney                NaN  21749.0
#
#                        wikipedia_id age
# state
# NY               Kirsten Gillibrand  54
# NY                    Yvette Clarke  56
# NY                    Brian Higgins  61
# NY                  Carolyn Maloney  75
# NY                    Gregory Meeks  67
# NY                     Jerry Nadler  73
# NY            Tom Reed (politician)  49
# NY                    Chuck Schumer  70
# NY                       Paul Tonko  71
# NY                  Nydia Velázquez  68
# NY                       Grace Meng  45
# NY                  Hakeem Jeffries  50
# NY             Sean Patrick Maloney  54
# NY                       Lee Zeldin  41
# NY                    Kathleen Rice  56
# NY                   Elise Stefanik  36
# NY                       John Katko  58
# NY                    Thomas Suozzi  58
# NY                Adriano Espaillat  66
# NY                   Joseph Morelle  63
# NY         Alexandria Ocasio-Cortez  31
# NY     Antonio Delgado (politician)  44
# NY        Chris Jacobs (politician)  54
# NY                 Andrew Garbarino  36
# NY               Nicole Malliotakis  40
# NY                   Ritchie Torres  33
# NY                    Jamaal Bowman  44
# NY                   Mondaire Jones  33
# NY                   Claudia Tenney  60
#
# [29 rows x 35 columns]

# %% [markdown]
# Use the loc command to find all legislators from South Carolina and North Carolina

# %%
legislators.index = legislators['state']
legislators.loc['SC']
# Out:
#       last_name first_name middle_name suffix nickname              full_name  \
# state
# SC       Graham    Lindsey          O.    NaN      NaN         Lindsey Graham
# SC      Clyburn      James          E.    NaN      Jim       James E. Clyburn
# SC       Duncan       Jeff         NaN    NaN      NaN            Jeff Duncan
# SC        Scott        Tim         NaN    NaN      NaN              Tim Scott
# SC       Wilson        Joe          G.    NaN      NaN             Joe Wilson
# SC         Rice        Tom         NaN    NaN      NaN               Tom Rice
# SC       Norman      Ralph         NaN    NaN      NaN           Ralph Norman
# SC      Timmons    William          R.    NaN      NaN  William R. Timmons IV
# SC         Mace      Nancy        Ruth    NaN      NaN             Nancy Mace
#
#         birthday gender type state  ...  lis_id              fec_ids  \
# state                               ...
# SC    1955-07-09      M  sen    SC  ...    S293  S0SC00149,H4SC03087
# SC    1940-07-21      M  rep    SC  ...     NaN            H2SC02042
# SC    1966-01-07      M  rep    SC  ...     NaN            H0SC03077
# SC    1965-09-19      M  sen    SC  ...    S365  H0SC01279,S4SC00240
# SC    1947-07-31      M  rep    SC  ...     NaN            H2SC02059
# SC    1957-08-04      M  rep    SC  ...     NaN            H2SC07066
# SC    1953-06-20      M  rep    SC  ...     NaN            H8SC05158
# SC    1984-04-30      M  rep    SC  ...     NaN            H8SC04250
# SC    1977-12-04      F  rep    SC  ...     NaN            H0SC01394
#
#         cspan_id govtrack_id votesmart_id             ballotpedia_id  \
# state
# SC       36782.0      300047      21992.0             Lindsey Graham
# SC       21607.0      400075      27066.0           James E. Clyburn
# SC       62713.0      412472      47967.0                Jeff Duncan
# SC      623506.0      412471      11940.0                  Tim Scott
# SC     1002567.0      400433       3985.0                 Joe Wilson
# SC       79473.0      412572     132382.0  Tom Rice (South Carolina)
# SC       61996.0      412738      47930.0               Ralph Norman
# SC           NaN      412815     168923.0            William Timmons
# SC           NaN      456843          NaN                 Nancy Mace
#
#       washington_post_id icpsr_id                      wikipedia_id age
# state
# SC                   NaN  29566.0                    Lindsey Graham  65
# SC                   NaN  39301.0                       Jim Clyburn  80
# SC                   NaN  21174.0          Jeff Duncan (politician)  55
# SC                   NaN  21173.0                         Tim Scott  55
# SC                   NaN  20138.0  Joe Wilson (American politician)  73
# SC                   NaN  21359.0                          Tom Rice  63
# SC                   NaN  21753.0                      Ralph Norman  67
# SC                   NaN  21974.0                   William Timmons  36
# SC                   NaN      NaN                        Nancy Mace  43
#
# [9 rows x 35 columns]

# %% [markdown]
# Use the loc command to retrieve all legislators from California, Oregon and Washington and only get their full name, state, party and age

# %%
legislators.loc[['CA', 'OR', 'WA'],['full_name', 'state', 'party', 'age']].head()
# Out:
#               full_name state       party  age
# state
# CA     Dianne Feinstein    CA    Democrat   87
# CA           Karen Bass    CA    Democrat   67
# CA          Ken Calvert    CA  Republican   67
# CA             Judy Chu    CA    Democrat   67
# CA            Jim Costa    CA    Democrat   68

# %%
legislators.iloc[0:10, [[0 :5]]
# Out:
#   File "<ipython-input-72-34515eb9d70f>", line 1
#     legislators.iloc[0:10, [[0 :5]]
#                                ^
# SyntaxError: invalid syntax
